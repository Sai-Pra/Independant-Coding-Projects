# %%
# Below are dependancies needed to run Selenium; I will be using a Chrome WebDriver to open up and run chrome from my ntoebook
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from IPython.display import clear_output

# I choose to open Chrome up in incognito, and point to where the Chrome WebDriver software is
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver = webdriver.Chrome('C:\webdriver\chromedriver.exe', chrome_options=chrome_options)

driver.get("https://www.google.com")

Search_Bar = driver.find_element(By.NAME,"q");
search = input("Please enter what you would like to search up: ")
Search_Bar.send_keys(search)
time.sleep(0.2)

Search_Bar.send_keys(Keys.ENTER)

def navigate_web():
    links = driver.find_elements(By.TAG_NAME,"a");


    length = 0;

    for i in links:
        if not (i.text == "" or i.text == " "):
            print("Option " + str(length) + ': "' + i.text + '"\n')
            length += 1

    print("Option " + str(length) + ": Next Page\n")
    print("Option " + str(length + 1) + ": End Program\n\n")
    
    print(str(length)+"\n\n")

    choice = int(input("Please choose which option you want by typing the number\n"))
    while not(int(choice) < length + 2 and int(choice) > -1):
        choice = int(input("Please choose which option you want by typing the number\n"))
    if (int(choice) < length-1 and int(choice) > -1):
        links[choice].click()
    elif(int(choice) - length == 0):
        nextButton = driver.find_element(By.ID, "pnnext")
        nextButton.click()
        clear_output(wait=True)
        navigate_web()
    elif(int(choice) - length == -1):  
        driver.close()

navigate_web()
# Out:
# C:\Users\saipr\AppData\Local\Temp\ipykernel_16764\1839937770.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\webdriver\chromedriver.exe', chrome_options=chrome_options)
# C:\Users\saipr\AppData\Local\Temp\ipykernel_16764\1839937770.py:12: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('C:\webdriver\chromedriver.exe', chrome_options=chrome_options)
# Please enter what you would like to search upSaipranav Venkatakrishnan
# Option 0: "Skip to main content"
#
# Option 1: "Switch to page by page results"
#
# Option 2: "Switch to continuous scrolling results"
#
# Option 3: "Accessibility help"
#
# Option 4: "Accessibility feedback"
#
# Option 5: "Sign in"
#
# Option 6: "News"
#
# Option 7: "Images"
#
# Option 8: "Videos"
#
# Option 9: "Shopping"
#
# Option 10: "Saipranav Venkatakrishnan - Palatine, Illinois, United States
# https://www.linkedin.com › saipranav-venkatakrishnan-0a..."
#
# Option 11: "Images for Saipranav Venkatakrishnan"
#
# Option 12: "boy scout"
#
# Option 13: "space station"
#
# Option 14: "troop 209"
#
# Option 15: "eagle scout"
#
# Option 16: "View all"
#
# Option 17: "View all"
#
# Option 18: "All about me by Saipranav Venkatakrishnan on Prezi Next
# https://prezi.com › all-about-me"
#
# Option 19: "'The future better watch out for Sai': Palatine teen earns rare ...
# https://www.dailyherald.com › news › the-future-better-w..."
#
# Option 20: "Palatine Boy Scout Earns Prestigious Conservation Award
# https://www.journal-topics.com › articles › palatine-boy..."
#
# Option 21: "Eagle Scout Court of Honor #1 - YouTube
# https://www.youtube.com › watch"
#
# Option 22: "PREVIEW
# 2:18:46"
#
# Option 23: "sai-venkatakrishnan Profiles - Facebook
# https://www.facebook.com › public › Sai-Venkatakrish..."
#
# Option 24: "Watch Space Launch Of Boy Scout Troop's Experiment ... - Patch
# https://patch.com › illinois › arlingtonheights › watch-s..."
#
# Option 25: "V.N. Venkatakrishnan's Web Site - Home Page
# https://www.cs.uic.edu › ~venkat"
#
# Option 26: "Saipranav"
#
# Option 27: "Pin on Sociology/Anthropology - McCreary - Pinterest
# https://www.pinterest.com › Explore › Event Planning"
#
# Option 28: "More results"
#
# Option 29: Next Page
#
# Option 30: End Program
#
#
# 29
#
#
# Please choose which option you want by typing the number
# 19
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [33], in <cell line: 52>()
#      49     elif(int(choice) - length == -1):
#      50         driver.close()
# ---> 52 navigate_web()
#
# Input In [33], in navigate_web()
#      41     choice = int(input("Please choose which option you want by typing the number\n"))
#      42 if (int(choice) < length-1 and int(choice) > -1):
# ---> 43     links[choice].click()
#      44 elif(int(choice) - length == 0):
#      45     nextButton = driver.find_element(By.ID, "pnnext")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=107.0.5304.62)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003F1ED3+2236115]
# 	Ordinal0 [0x003892F1+1807089]
# 	Ordinal0 [0x002965C0+812480]
# 	Ordinal0 [0x002C6586+1009030]
# 	Ordinal0 [0x002BC416+967702]
# 	Ordinal0 [0x002E1A8C+1120908]
# 	Ordinal0 [0x002BBD84+966020]
# 	Ordinal0 [0x002E1CA4+1121444]
# 	Ordinal0 [0x002F59E2+1202658]
# 	Ordinal0 [0x002E18A6+1120422]
# 	Ordinal0 [0x002BA73D+960317]
# 	Ordinal0 [0x002BB71F+964383]
# 	GetHandleVerifier [0x0069E7E2+2743074]
# 	GetHandleVerifier [0x006908D4+2685972]
# 	GetHandleVerifier [0x00482BAA+532202]
# 	GetHandleVerifier [0x00481990+527568]
# 	Ordinal0 [0x0039080C+1837068]
# 	Ordinal0 [0x00394CD8+1854680]
# 	Ordinal0 [0x00394DC5+1854917]
# 	Ordinal0 [0x0039ED64+1895780]
# 	BaseThreadInitThunk [0x759F6739+25]
# 	RtlGetFullPathName_UEx [0x76FF8FD2+1218]
# 	RtlGetFullPathName_UEx [0x76FF8F9D+1165]

# %%
# Below are dependancies needed to run Selenium; I will be using a Chrome WebDriver to open up and run chrome from my ntoebook
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# I choose to open Chrome up in incognito, and point to where the Chrome WebDriver software is
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver = webdriver.Chrome('C:\webdriver\chromedriver.exe', chrome_options=chrome_options)

driver.get("https://www.google.com/search?q=Spotify&source=hp&ei=YQRbY9KPMZifptQP9uyW2AU&iflsig=AJiK0e8AAAAAY1sScUxSEXUpSE43vQwcbzqKHJi8zpnd&ved=0ahUKEwiSxPX8uIH7AhWYj4kEHXa2BVsQ4dUDCAo&uact=5&oq=Spotify&gs_lcp=Cgdnd3Mtd2l6EAMyDgguEIAEELEDEMcBENEDMgsIABCABBCxAxCDATILCAAQgAQQsQMQgwEyCAgAEIAEELEDMgsIABCABBCxAxCDATIICAAQgAQQsQMyCAgAEIAEELEDMgsIABCABBCxAxCDATIFCAAQgAQyCwgAEIAEELEDEIMBUABYCWDpAWgAcAB4AoABOogBygGSAQE0mAEAoAEB&sclient=gws-wiz")

nextButton = driver.find_element(By.ID, "pnnext")

print(nextButton.text)
nextButton.click()
